# %%
import pandas as pd
import os
import sys

sys.path.append("../")

# %%
data_path = "../data/processed/"

# %%
# read in the data and set the index as 'event_id_cnty'
df = pd.read_parquet(os.path.join(data_path, 'text_base.parquet'))

# %%
df
